# %% [markdown]
# Cú pháp cơ bản

# %%
# 1. kiểu dữ liệu và biến 
"""
- các kiểu dữ liệu
+ int số nguyên 4,-2,54,..
+ float số thực 5.342,-43,3.14,...
+ str string kí tự "string"
+ bool đúng sai True False 
để kiểm tra kiểu dữ liệu sử dụng hàm type()
"""
# 2 nhập và in ra màn hình. 
# input nhập dữ liệu từ bàn phím
# print in ra các dữ liệu ra màn hình,... 
# hàm print có 2 tham số là sep và end

# 3.toán tử.
"""
+ toán tử số học: +,-,*,/,//,**,%
+ toán tử so sánh: >, <, >=, <=, ==, !=.
+ toán tử logic: and or not 
+ toán tử gán bằng: +=, -=, *=, /=, //=, **=, %=,...
"""

# 4. biểu thức điều kiện if else elif
"""
if đk đúng:
    code 
elif đk đúng:
    code 
else:
    code
"""
# 5. vòng lặp for while
# 7. hàm
