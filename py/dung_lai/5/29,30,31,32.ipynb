# %%
def calc_total_price(apple_weight,APP_PRICE):
    return apple_weight * APP_PRICE

def calc_return(total_price,money_given):
    if money_given < total_price:
        return -1
    return money_given - total_price

def print_ruturn_info(total):
    # 500 200 100 20 10 1
    # 502 % 500 = 2
    # 31 % 3 = 1
    count_500 = int(total/500)
    lef_over = total - 500*count_500
    if count_500 != 0:
        print("500k: "+ str(count_500))

    count_200 = int(total/200)
    total = total - 200*count_200
    if count_200 != 0:
        print("200k: "+ str(count_200))

    count_100 = int(total/100)
    total = total - 100*count_100
    if count_100 != 0:
        print("100k: "+ str(count_100))


    count_50 = int(total/50)
    total = total - 50*count_50
    if count_50 != 0:
        print("50k: "+ str(count_50))

    count_20 = int(total/20)
    total = total - 20*count_20
    if count_20 != 0:
        print("20k: "+ str(count_20))

    count_10 = int(total/10)
    total = total - 10*count_10
    if count_10 != 0:
        print("10k: "+ str(count_10))
    
    count_1 = int(total)
    if total != 0:
        print("1k: "+ str(count_1))

def main():
    APP_PRICE = 21 # K VND
    apple_weight = float(input("Enter weight of apples: ")) # cân nặng của quả táo đó
    money_given = float(input("Total money customer give you: ")) # số tiền người khác đưa cho bạn.

    total_price = calc_total_price(apple_weight,APP_PRICE) # tổng số tiền mà người mua cần trả
    money_return = calc_return(total_price,money_given) # số tiền người mua đưa

    print("Total price: "+ str(int(total_price)))
    if money_return == -1:
        print("Not enough cash") # thiếu tiền
    else:
        print("You need to return to customer: "+str(round(money_return,2)))
        print_ruturn_info(money_return)
main()
# Out:
# Total price: 142
# You need to return to customer: 357.2
# 200k: 1
# 100k: 1
# 50k: 1
# 1k: 7
