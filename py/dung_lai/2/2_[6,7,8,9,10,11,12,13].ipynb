# %%
# 6
# data type: kiểu dữ liệu.

# string chuỗi
# int số nguyên
# foat số thực
# boolean bool kiểu dữ liệu đúng sai True False 

# variable: biến là cái thay đổi được
# var trong pascal 
print(123) # để in ra màn hình

# phần ghi chú của code là #
firsname = "trung"
print(firsname)

# một số lỗi thường gặp

# print(firsnames)

# NameError: name 'firsnames' is not defined. Did you mean: 'firsname'? ==> lỗi biến chưa được đặt tên
# Out:
# 123
# trung

# %%
# 7 

# input() hàm có sẵn built-in function có tác dụng nhập từ bàn phím.

CURRENT_YEAR = 2025

firstName = input("your firstname: ")
lastname = input("your last name: ")
year_born = int(input("when you were born: "))

# nếu không ép kiểu sẽ có lỗi này TypeError: unsupported operand type(s) for -: 'int' and 'str'
# lỗi này có nghĩa là không hỗ trợ trừ cho kiểu int và kiểu str
age = CURRENT_YEAR - year_born

print("Your name is "+ firstName + " " + lastname)
print("You are " + str(age) + " years old in " + str(CURRENT_YEAR))
# Out:
# Your name is 5 3
# You are 2002 years old in2025

# %%
# 8

CURRENT_YEAR = 2025
METER_TO_FEET = 3.281
firstName = input("your firstname: ")
lastname = input("your last name: ")
year_born = int(input("when you were born: "))

age = CURRENT_YEAR - year_born
height_meter = float(input("Your height (meter): "))
height_feet = height_meter * METER_TO_FEET


print("Your name is "+ firstName + " " + lastname)
print("You are " + str(age) + " years old in " + str(CURRENT_YEAR))
print(f"You are {round(height_feet,1)} feet tall")

# hoặc sử dụng string format 
# print("You are {0} feet tall".format(round(height_feet,1)))
# Out:
# Your name is trung  tran
# You are 18 years old in2025
# You are 5.2 feet tall

# %%
# 9 if else
age = 1

if age < 10:
    print("con nit")
elif age < 18:
    print("tre trâu")
    if age >= 15 and age <= 17:
        print("siêu trẻ trâu")
else:print("người lớn")
# Out:
# con nit

# %%
# 10 boolean

# if True:
#     # luôn luôn chạy dòng code này 

age = 16 
is_con_nit = 16 # default # initialise the variable
# lỗi invalid syntax là cú pháp không có hiệu lực
# not True ==> False
if age < 10: 
    is_con_nit = True
if is_con_nit:
    print("trẻ trâu")
    if age >= 15 and age <= 17:
        print("siêu trẻ trâu")
else: print("người lớn")
# Out:
# trẻ trâu
# siêu trẻ trâu

# %%
# 11

# T and T ==> T
# T and F ==> F
# F and T ==> F
# F and F ==> F

# T or T ==> T
# T or F ==> T
# F or T ==> T
# F or F ==> F

# not T ==> F
# not F ==> T

# %%
# 12

CURRENT_YEAR = 2025
METER_TO_FEET = 3.281
firstName = input("your firstname: ")
lastname = input("your last name: ")
year_born = int(input("when you were born: "))

age = CURRENT_YEAR - year_born
height_meter = float(input("Your height (meter): "))
height_feet = height_meter * METER_TO_FEET

print("\n____")

print("Your name is "+ firstName + " " + lastname)
print("You are " + str(age) + " years old in " + str(CURRENT_YEAR))
print(f"You are {round(height_feet,1)} feet tall")

gender_input = input("Are you male (yes/no): ")
is_male = None

if gender_input == "yes":
    is_male = True
elif gender_input == "no":
    is_male = False
else:is_male = None
# Out:
# ____
# Your name is trung tran
# You are 18 years old in 2025
# You are 5.2 feet tall

# %%
# 13
CURRENT_YEAR = 2025
METER_TO_FEET = 3.281
firstName = input("your firstname: ")
lastname = input("your last name: ")
year_born = int(input("when you were born: "))

age = CURRENT_YEAR - year_born
height_meter = float(input("Your height (meter): "))
height_feet = height_meter * METER_TO_FEET

print("\n____")

print("Your name is "+ firstName + " " + lastname)
print("You are " + str(age) + " years old in " + str(CURRENT_YEAR))
print(f"You are {round(height_feet,1)} feet tall")

gender_input = input("Are you male (yes/no): ")
is_male = None

if (gender_input == "yes") or( gender_input == "Y") or (gender_input == "Yes"):
    is_male = True
elif (gender_input == "no") or (gender_input == "N") or (gender_input == "No"):
    is_male = False
else:is_male = None

# is có thể thay thế ==
if is_male is None:
    print("Invalid Answer")
elif is_male == True:
    if height_feet > 6.5:
           print("You are very tall as a man")
    if height_feet > 6.0:
        print("You are tall as a man")
    else:
        print("Yor are short as a man")
elif is_male == False:
    if height_feet > 5.7:
        print("Yor are tall as a girl")
    else:
        print("Yor are short as a girl")
else:
    print("System error: Variable 'is_male' is not correct")
# Out:
# ____
# Your name is tran trung
# You are 18 years old in 2025
# You are 6.1 feet tall
# You are tall as a man
