# %%
# 14

# print(1)
# print(2)
# print(3)
# print(4)
# print(5)

# thay vì sử dụng nhiều câu lệnh print thì chúng ta có thể sử dụng vòng lặp 

# For loop 
# range(start,stop,step)
for i  in range(0,5):
    # từ i viết tắt từ index 
    print(i+1)
print("_")
# để in ra 5 4 3 2 1
for i in range(0,5):
    print(5-i)

print("_")
# để in ra 1 3 5 7
for i in range(4):
    print(i*2+1,end=" ")
print("\n_")
for i in range(1,8,2):
    print(i,end=" ")
# Out:
# 1
# 2
# 3
# 4
# 5
# _
# 5
# 4
# 3
# 2
# 1
# _
# 1 3 5 7
# _
# 1 3 5 7

# %%
# 15
# for loop in loop 
# loop in loop 1
for i in range(3):
    print(i,end=" ")
    for j in range(3,5):
        print(j,end=" ")

# 3 4 0 3 4 1 3 4 2
# Out:
# 0 3 4 1 3 4 2 3 4 3
# 4
# 0
# 3
# 4
# 1
# 3
# 4
# 2

# %%
# loop in loop 2
for i in range(3):
    for j in range(3,5):
        print(j)
    print(i)
# Out:
# 3
# 4
# 0
# 3
# 4
# 1
# 3
# 4
# 2

# %%
# loop in loop 3
for i in range(2):
    for j in range(3,5):
        print(j)
        print(i)
# 3 0 4 0 3 1 4 1
# Out:
# 3
# 0
# 4
# 0
# 3
# 1
# 4
# 1

# %%
# 16 
# break dừng hẳn vòng lặp luôn
# continue bỏ qua và chạy vòn tiếp theo

for i in range(1,10):
    if i == 5:
        continue
    print(i,end=" ")

print("\n-----")

for i in range(1,10):
    if i == 5:break
    print(i,end=" ")
# Out:
# 1 2 3 4 6 7 8 9
# -----
# 1 2 3 4

# %% [markdown]
# 17.làm bài tập
#
#
#
# ![3BT.png](attachment:3BT.png)

# %%
sum = 0
for i in range(3,100,2):
    sum+=1/i
print(round(1/sum,2))
# Out:
# 0.52

# %%
sum = 0

for i in range(1,100):
    if i == 1:continue
    elif i % 2 == 0:continue
    else:sum += 1/i 
print(round(1/sum,2))
# Out:
# 0.52

# %%
# 19
CURRENT_YEAR = 2025
METER_TO_FEET = 3.281
firstName = input("your firstname: ")
lastname = input("your last name: ")
year_born = int(input("when you were born: "))

age = CURRENT_YEAR - year_born
height_meter = float(input("Your height (meter): "))
height_feet = height_meter * METER_TO_FEET

print("\n____")

print("Your name is "+ firstName + " " + lastname)
print("You are " + str(age) + " years old in " + str(CURRENT_YEAR))
print(f"You are {round(height_feet,1)} feet tall")

gender_input = input("Are you male (yes/no): ")
is_male = None

if (gender_input == "yes") or( gender_input == "Y") or (gender_input == "Yes"):
    is_male = True
    
# nếu mà thay elif ở dưới này thành if thì sẽ xẩy ra là ở dưới đây là 1 khối lệnh khác chứ không liên quan đến lệnh trên nên phải dùng elif
elif (gender_input == "no") or (gender_input == "N") or (gender_input == "No"):
    is_male = False
else:is_male = None

# is có thể thay thế ==
if is_male is None:
    print("Invalid Answer")
elif is_male == True:
    if height_feet > 6.5:
           print("You are very tall as a man")
    if height_feet > 6.0:
        print("You are tall as a man")
    else:
        print("Yor are short as a man")
elif is_male == False:
    if height_feet > 5.7:
        print("Yor are tall as a girl")
    else:
        print("Yor are short as a girl")
else:
    print("System error: Variable 'is_male' is not correct")
# Out:
# ____
# Your name is tran  trung
# You are 18 years old in 2025
# You are 5.6 feet tall
# Yor are short as a man

# %%
# 20

CURRENT_YEAR = 2025
METER_TO_FEET = 3.281
firstName = input("your firstname: ")
lastname = input("your last name: ")
year_born = int(input("when you were born: "))
height_meter = float(input("Your height (meter): "))
gender_input = input("Are you male (yes/no): ")

age = CURRENT_YEAR - year_born
height_feet = height_meter * METER_TO_FEET

print("\n____")

print("Your name is "+ firstName + " " + lastname)
print("You are " + str(age) + " years old in " + str(CURRENT_YEAR))
print(f"You are {round(height_feet,1)} feet tall")

is_male = None

if (gender_input == "yes") or( gender_input == "Y") or (gender_input == "Yes"):
    is_male = True

elif (gender_input == "no") or (gender_input == "N") or (gender_input == "No"):
    is_male = False
else:is_male = None

if is_male is None:
    print("Invalid Answer")
elif is_male == True:
    if height_feet > 6.5:
        print("You are",end=" ")

        for i in range(1,10):
            print("very",end=" ")

        print("tall as a man")
    elif height_feet > 6.0:
        print("You are tall as a man")
    else:
        print("Yor are short as a man")
elif is_male == False:
    if height_feet > 5.7:
        print("Yor are tall as a girl")
    elif height_feet < 5.0:
        print("You are",end=" ")

        i = 0
        while i < 10 :
            print("very",end=" ")
            i+=1

        print("short as a girl")
    else:
        print("Yor are short as a girl")
else:
    print("System error: Variable 'is_male' is not correct")
# Out:
# ____
# Your name is trna trung
# You are 18 years old in 2025
# You are 4.5 feet tall
# You are very very very very very very very very very very short as a girl

# %%
# 21

CURRENT_YEAR = 2025
METER_TO_FEET = 3.281
firstName = input("your firstname: ")
lastname = input("your last name: ")
year_born = int(input("when you were born: "))
height_meter = float(input("Your height (meter): "))
while True:
    gender_input = input("Are you male (yes/no): ")
    if (gender_input == "yes") or (gender_input == "no"):
        break

age = CURRENT_YEAR - year_born
height_feet = height_meter * METER_TO_FEET

print("\n____")

print("Your name is "+ firstName + " " + lastname)
print("You are " + str(age) + " years old in " + str(CURRENT_YEAR))
print(f"You are {round(height_feet,1)} feet tall")

is_male = None

if (gender_input == "yes") :
    is_male = True

elif (gender_input == "no") :
    is_male = False

if is_male == True:
    if height_feet > 6.5:
        print("You are",end=" ")

        for i in range(1,10):
            print("very",end=" ")

        print("tall as a man")
    elif height_feet > 6.0:
        print("You are tall as a man")
    else:
        print("Yor are short as a man")
elif is_male == False:
    if height_feet > 5.7:
        print("Yor are tall as a girl")
    elif height_feet < 5.0:
        print("You are",end=" ")

        i = 0
        while i < 10 :
            print("very",end=" ")
            i+=1

        print("short as a girl")
    else:
        print("Yor are short as a girl")
# Out:
# ____
# Your name is quoc trung
# You are 18 years old in 2025
# You are 6.9 feet tall
# You are very very very very very very very very very tall as a man
